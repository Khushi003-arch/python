# %%
print("Hello Khushi! Jupyter Notebook chal raha hai.")
# Out:
# Hello Khushi! Jupyter Notebook chal raha hai.

# %%
import pandas as pd 
country=['india','pakistan','usa','nepal']
pd.Series(country)
# Out:
# 0       india
# 1    pakistan
# 2         usa
# 3       nepal
# dtype: str
